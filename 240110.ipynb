# %%
# mid03
n = int(input())
a=[input() for _ in range(n)]
b=[x for x in a if'.jpg' in x or '.png' in x]
print(b)
# Out:
# 3
# py.py
# a.jpg
# b.png
# ['a.jpg', 'b.png']

# %%
import pandas as pd

# %%
df = pd.DataFrame([['Kim',21,92],['Lee',33,98],['Park',19,87]])
df
# Out:
#       0   1   2
# 0   Kim  21  92
# 1   Lee  33  98
# 2  Park  19  87

# %%
df2 = pd.DataFrame({'name':['Kim','Lee','Park'],'age':[27,19,33],'score':[100,90,80]})
df2
# Out:
#    name  age  score
# 0   Kim   27    100
# 1   Lee   19     90
# 2  Park   33     80

# %%
import pandas as pd
df3 = pd.read_csv('data.csv',encoding='UTF-8')
df3
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-97fd65359d87> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df3 = pd.read_csv('data.csv',encoding='UTF-8')
#       3 df3
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import pandas as pd
df4 = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv', delimiter=\t')
df4
# Out:
#   File "<ipython-input-19-935d791e1c03>", line 2
#     df4 = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv', delimiter=\t')
#                                                                                                     ^
# SyntaxError: unexpected character after line continuation character

# %%
import pandas as pd
df5 = pd.read_excel('data.xlsx')
df5
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-cc7cd0b92d24> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df5 = pd.read_excel('data.xlsx')
#       3 df5
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head(2)
# Out:
#      0   1   2
# 0  Kim  21  92
# 1  Lee  33  98

# %%
df2.tail(2)
# Out:
#    name  age  score
# 1   Lee   19     90
# 2  Park   33     80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      int64
#  2   2       3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   score   3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes

# %%
df2.name
# Out:
# 0     Kim
# 1     Lee
# 2    Park
# Name: name, dtype: object

# %%
df2['name']
# Out:
# 0     Kim
# 1     Lee
# 2    Park
# Name: name, dtype: object

# %%
df2[['name','age']]
# Out:
#    name  age
# 0   Kim   27
# 1   Lee   19
# 2  Park   33

# %%
df2[0:2]
# Out:
#   name  age  score
# 0  Kim   27    100
# 1  Lee   19     90

# %%
df2['name'][0:2]
# Out:
# 0    Kim
# 1    Lee
# Name: name, dtype: object

# %%
df2.describe()
# Out:
#              age  score
# count   3.000000    3.0
# mean   26.333333   90.0
# std     7.023769   10.0
# min    19.000000   80.0
# 25%    23.000000   85.0
# 50%    27.000000   90.0
# 75%    30.000000   95.0
# max    33.000000  100.0

# %%
df2['name'].value_counts()
# Out:
# Kim     1
# Lee     1
# Park    1
# Name: name, dtype: int64

# %%
# mission
pd6 = pd.read_excel('BoxOffice.xlsx')
pd6
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-a2fd24dd8394> in <cell line: 2>()
#       1 # mission
# ----> 2 pd6 = pd.read_excel('BoxOffice.xlsx')
#       3 pd6
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
